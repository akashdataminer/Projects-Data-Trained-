# %% [raw]
# # DATA DESCRIPTION:-
#
# The task in this project is to predict the sales from different channels of advertisements such as TV, radio and newspaper. We have to use multiple regression algorithms and choose the model with best predictions.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os 
import warnings
warnings.filterwarnings("ignore")

# Importing the Libraries required to perform EDA

# %%
ds=pd.read_csv("Advertising_Data.csv")
ds

# Importing the Dataset into Python from the system
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
sales=pd.DataFrame(data=ds)
sales

# Giving the Dataset a Structured Format using DataFrame function and storing it in variable "sales"
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
pd.set_option("display.max_rows",None)

# Passing the function to display all rows and columns of the Dataset to have a clear view of the large dataset

# %%
sales
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# 5             6    8.7   48.9       75.0    7.2
# 6             7   57.5   32.8       23.5   11.8
# 7             8  120.2   19.6       11.6   13.2
# 8             9    8.6    2.1        1.0    4.8
# 9            10  199.8    2.6       21.2   10.6
# 10           11   66.1    5.8       24.2    8.6
# 11           12  214.7   24.0        4.0   17.4
# 12           13   23.8   35.1       65.9    9.2
# 13           14   97.5    7.6        7.2    9.7
# 14           15  204.1   32.9       46.0   19.0
# 15           16  195.4   47.7       52.9   22.4
# 16           17   67.8   36.6      114.0   12.5
# 17           18  281.4   39.6       55.8   24.4
# 18           19   69.2   20.5       18.3   11.3
# ...

# %% [markdown]
# # EDA (Exploratory Data Analysis):-

# %%
sales.columns

# Returning the names of all the columns of the dataset
# Out:
# Index(['Unnamed: 0', 'TV', 'radio', 'newspaper', 'sales'], dtype='object')

# %%
sales.info()

# It is providing the information of the data types and null values
# We can see that there are no null values present in the Dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   radio       200 non-null    float64
#  3   newspaper   200 non-null    float64
#  4   sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %% [markdown]
# ### Checking for Missing Values:-

# %%
sales.isnull().sum()

# After checking for missing values, we can see that there are no null values present in the Dataset
# Out:
# Unnamed: 0    0
# TV            0
# radio         0
# newspaper     0
# sales         0
# dtype: int64

# %% [markdown]
# ### Checking Correlation:-

# %%
sales_corr=sales.corr()
sales_corr

# Checking the correlation between the independent variables and the target variable
# Out:
#             Unnamed: 0        TV     radio  newspaper     sales
# Unnamed: 0    1.000000  0.017715 -0.110680  -0.154944 -0.051616
# TV            0.017715  1.000000  0.054809   0.056648  0.782224
# radio        -0.110680  0.054809  1.000000   0.354104  0.576223
# newspaper    -0.154944  0.056648  0.354104   1.000000  0.228299
# sales        -0.051616  0.782224  0.576223   0.228299  1.000000

# %%
plt.figure(figsize=(7,7))
sns.heatmap(sales_corr, annot=True, linewidths=2, linecolor="black", cmap="coolwarm_r")

# Graphical presentation of correlation between variables
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Checking Outliers:-

# %%
sales.quantile([0.05,0.1,0.2,0.25,0.3,0.4,0.5,0.6,0.7,0.75,0.8,0.9,0.95,0.96,0.97,0.98,0.99,1]).T

# Using the Percentile method to check the presence of outliers at percentiles between 5th and 100th percentile
# Out:
#               0.05   0.10   0.20    0.25   0.30    0.40    0.50    0.60  \
# Unnamed: 0  10.950  20.90  40.80  50.750  60.70   80.60  100.50  120.40
# TV          13.195  24.88  59.18  74.375  86.75  119.00  149.75  186.06
# radio        1.995   3.40   7.68   9.975  11.94   17.12   22.90   27.86
# newspaper    3.600   5.99   9.38  12.750  15.97   21.32   25.75   32.70
# sales        6.600   7.96   9.70  10.375  10.87   11.80   12.90   14.80
#
#               0.70     0.75    0.80    0.90     0.95     0.96     0.97  \
# Unnamed: 0  140.30  150.250  160.20  180.10  190.050  192.040  194.030
# TV          210.73  218.825  228.54  261.44  280.735  283.628  286.048
# radio        33.50   36.525   38.92   43.52   46.810   47.704   48.900
# newspaper    39.11   45.100   49.64   59.07   71.825   73.432   75.018
# sales        16.60   17.400   18.92   21.71   23.800   24.208   24.721
#
#                0.98     0.99   1.00
# Unnamed: 0  196.020  198.010  200.0
# ...

# %%
sales["TV"].plot.box()

# There are no outliers present in TV column
# Out:
# <AxesSubplot:>

# %%
sales["radio"].plot.box()

# There are no outliers present in radio column
# Out:
# <AxesSubplot:>

# %%
sales["newspaper"].plot.box()

# There are 2 outliers present in newspaper column
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Checking Skewness:-

# %%
sales.skew()

# Checking for the skewness in the dataset
# We found that except newspaper all other variables skewness is within range of +0.5 to -0.5
# Out:
# Unnamed: 0    0.000000
# TV           -0.069853
# radio         0.094175
# newspaper     0.894720
# sales         0.407571
# dtype: float64

# %%
sns.distplot(sales["TV"])

# Distribution plot of TV shows that data is almost normally distributed
# Out:
# <AxesSubplot:xlabel='TV', ylabel='Density'>

# %%
sns.distplot(sales["radio"])

# Distribution plot of radio shows that data is almost normally distributed
# Out:
# <AxesSubplot:xlabel='radio', ylabel='Density'>

# %%
sns.distplot(sales["newspaper"])

# The data in newspaper is right skewed
# Out:
# <AxesSubplot:xlabel='newspaper', ylabel='Density'>

# %% [markdown]
# ### Outlier Treatment:-

# %%
from scipy.stats import zscore

# Importing Z Score from Scipy Library

# %%
z=np.abs(zscore(sales))

# Taking absolute of z score to get the Data within Positive Standard Deviation

# %%
z
# Out:
# array([[1.72341210e+00, 9.69852266e-01, 9.81522472e-01, 1.77894547e+00,
#         1.55205313e+00],
#        [1.70609137e+00, 1.19737623e+00, 1.08280781e+00, 6.69578760e-01,
#         6.96046111e-01],
#        [1.68877065e+00, 1.51615499e+00, 1.52846331e+00, 1.78354865e+00,
#         9.07405869e-01],
#        [1.67144992e+00, 5.20496822e-02, 1.21785493e+00, 1.28640506e+00,
#         8.60330287e-01],
#        [1.65412920e+00, 3.94182198e-01, 8.41613655e-01, 1.28180188e+00,
#         2.15683025e-01],
#        [1.63680847e+00, 1.61540845e+00, 1.73103399e+00, 2.04592999e+00,
#         1.31091086e+00],
#        [1.61948775e+00, 1.04557682e+00, 6.43904671e-01, 3.24708413e-01,
#         4.27042783e-01],
#        [1.60216702e+00, 3.13436589e-01, 2.47406325e-01, 8.72486994e-01,
#         1.58039455e-01],
#        [1.58484630e+00, 1.61657614e+00, 1.42906863e+00, 1.36042422e+00,
#         1.77205942e+00],
#        [1.56752558e+00, 6.16042873e-01, 1.39530685e+00, 4.30581584e-01,
# ...

# %%
print(np.where(z>3))

# Taking all the integer locations of data points where Z score value is greater than +3 Standard Deviation
# All such points denote the outliers integer locations
# Out:
# (array([ 16, 101], dtype=int64), array([3, 3], dtype=int64))

# %%
z[16,3]

# This is the integer location of first outlier
# Out:
# 3.8411707150992718

# %%
z[101,3]

# This is the integer location of last outlier
# Out:
# 3.238153957342154

# %%
sales_new=sales[(z<3).all(axis=1)]
sales_new

# Taking all the values within +3 Standard Deviation and saving it in variable sales_new
# This new dataset contains all the values without outliers
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# 5             6    8.7   48.9       75.0    7.2
# 6             7   57.5   32.8       23.5   11.8
# 7             8  120.2   19.6       11.6   13.2
# 8             9    8.6    2.1        1.0    4.8
# 9            10  199.8    2.6       21.2   10.6
# 10           11   66.1    5.8       24.2    8.6
# 11           12  214.7   24.0        4.0   17.4
# 12           13   23.8   35.1       65.9    9.2
# 13           14   97.5    7.6        7.2    9.7
# 14           15  204.1   32.9       46.0   19.0
# 15           16  195.4   47.7       52.9   22.4
# 17           18  281.4   39.6       55.8   24.4
# 18           19   69.2   20.5       18.3   11.3
# 19           20  147.3   23.9       19.1   14.6
# ...

# %%
sales.shape
# Out:
# (200, 5)

# %%
sales_new.shape
# Out:
# (198, 5)

# %%
data_loss=((200-198)/200)*100
data_loss

# Since the Data Loss is only 1% therefore we can drop the outliers
# Out:
# 1.0

# %% [raw]
# # Since the Data Loss is only 1% therefore we can drop the outliers

# %%
sales=sales_new
sales.shape

# Assigning the Outlier free new dataset to "sales" variable
# Out:
# (198, 5)

# %%
sales
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# 5             6    8.7   48.9       75.0    7.2
# 6             7   57.5   32.8       23.5   11.8
# 7             8  120.2   19.6       11.6   13.2
# 8             9    8.6    2.1        1.0    4.8
# 9            10  199.8    2.6       21.2   10.6
# 10           11   66.1    5.8       24.2    8.6
# 11           12  214.7   24.0        4.0   17.4
# 12           13   23.8   35.1       65.9    9.2
# 13           14   97.5    7.6        7.2    9.7
# 14           15  204.1   32.9       46.0   19.0
# 15           16  195.4   47.7       52.9   22.4
# 17           18  281.4   39.6       55.8   24.4
# 18           19   69.2   20.5       18.3   11.3
# 19           20  147.3   23.9       19.1   14.6
# ...

# %% [markdown]
# ### Skewness Treatment:-

# %%
sales.skew()

# Checking the skewness of the dataset and only newspaper column is over skewed
# Out:
# Unnamed: 0   -0.006283
# TV           -0.082332
# radio         0.114842
# newspaper     0.650112
# sales         0.407130
# dtype: float64

# %%
sales["newspaper"].skew()

# Getting the Skewness of newspaper column
# Out:
# 0.650111551724088

# %%
sales["newspaper"]=np.sqrt(sales["newspaper"])

# Apllying Square Root Transform function to treat the skewness

# %%
sales["newspaper"].skew()

# Getting the improved skewness of the newspaper column
# Out:
# -0.040649472621842535

# %%
sales
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 0             1  230.1   37.8   8.318654   22.1
# 1             2   44.5   39.3   6.715653   10.4
# 2             3   17.2   45.9   8.324662    9.3
# 3             4  151.5   41.3   7.648529   18.5
# 4             5  180.8   10.8   7.641989   12.9
# 5             6    8.7   48.9   8.660254    7.2
# 6             7   57.5   32.8   4.847680   11.8
# 7             8  120.2   19.6   3.405877   13.2
# 8             9    8.6    2.1   1.000000    4.8
# 9            10  199.8    2.6   4.604346   10.6
# 10           11   66.1    5.8   4.919350    8.6
# 11           12  214.7   24.0   2.000000   17.4
# 12           13   23.8   35.1   8.117881    9.2
# 13           14   97.5    7.6   2.683282    9.7
# 14           15  204.1   32.9   6.782330   19.0
# 15           16  195.4   47.7   7.273239   22.4
# 17           18  281.4   39.6   7.469940   24.4
# 18           19   69.2   20.5   4.277850   11.3
# 19           20  147.3   23.9   4.370355   14.6
# ...

# %% [markdown]
# ### Splitting the data into Train & Test:-

# %%
sales.drop(columns=["Unnamed: 0"],inplace=True)
sales

# Dropping the "Unnamed: 0" column as it has no relation with the target variable
# Out:
#         TV  radio  newspaper  sales
# 0    230.1   37.8   8.318654   22.1
# 1     44.5   39.3   6.715653   10.4
# 2     17.2   45.9   8.324662    9.3
# 3    151.5   41.3   7.648529   18.5
# 4    180.8   10.8   7.641989   12.9
# 5      8.7   48.9   8.660254    7.2
# 6     57.5   32.8   4.847680   11.8
# 7    120.2   19.6   3.405877   13.2
# 8      8.6    2.1   1.000000    4.8
# 9    199.8    2.6   4.604346   10.6
# 10    66.1    5.8   4.919350    8.6
# 11   214.7   24.0   2.000000   17.4
# 12    23.8   35.1   8.117881    9.2
# 13    97.5    7.6   2.683282    9.7
# 14   204.1   32.9   6.782330   19.0
# 15   195.4   47.7   7.273239   22.4
# 17   281.4   39.6   7.469940   24.4
# 18    69.2   20.5   4.277850   11.3
# 19   147.3   23.9   4.370355   14.6
# 20   218.4   27.7   7.307530   18.0
# 21   237.4    5.1   4.847680   12.5
# 22    13.2   15.9   7.042727    5.6
# 23   228.3   16.9   5.118594   15.5
# 24    62.3   12.6   4.277850    9.7
# 25   262.9    3.5   4.415880   12.0
# ...

# %%
x=sales.iloc[:,0:-1]
x

# Taking all the independent variables into x
# Out:
#         TV  radio  newspaper
# 0    230.1   37.8   8.318654
# 1     44.5   39.3   6.715653
# 2     17.2   45.9   8.324662
# 3    151.5   41.3   7.648529
# 4    180.8   10.8   7.641989
# 5      8.7   48.9   8.660254
# 6     57.5   32.8   4.847680
# 7    120.2   19.6   3.405877
# 8      8.6    2.1   1.000000
# 9    199.8    2.6   4.604346
# 10    66.1    5.8   4.919350
# 11   214.7   24.0   2.000000
# 12    23.8   35.1   8.117881
# 13    97.5    7.6   2.683282
# 14   204.1   32.9   6.782330
# 15   195.4   47.7   7.273239
# 17   281.4   39.6   7.469940
# 18    69.2   20.5   4.277850
# 19   147.3   23.9   4.370355
# 20   218.4   27.7   7.307530
# 21   237.4    5.1   4.847680
# 22    13.2   15.9   7.042727
# 23   228.3   16.9   5.118594
# 24    62.3   12.6   4.277850
# 25   262.9    3.5   4.415880
# 26   142.9   29.3   3.549648
# 27   240.1   16.7   4.785394
# 28   248.8   27.1   4.785394
# 29    70.6   16.0   6.387488
# 30   292.9   28.3   6.572671
# 31   112.9   17.4   6.212890
# ...

# %%
y=sales.iloc[:,-1]
y

# Taking the target variable in y
# Out:
# 0      22.1
# 1      10.4
# 2       9.3
# 3      18.5
# 4      12.9
# 5       7.2
# 6      11.8
# 7      13.2
# 8       4.8
# 9      10.6
# 10      8.6
# 11     17.4
# 12      9.2
# 13      9.7
# 14     19.0
# 15     22.4
# 17     24.4
# 18     11.3
# 19     14.6
# 20     18.0
# 21     12.5
# 22      5.6
# 23     15.5
# 24      9.7
# 25     12.0
# 26     15.0
# 27     15.9
# 28     18.9
# 29     10.5
# 30     21.4
# 31     11.9
# 32      9.6
# 33     17.4
# 34      9.5
# 35     12.8
# 36     25.4
# 37     14.7
# 38     10.1
# 39     21.5
# 40     16.6
# 41     17.1
# 42     20.7
# 43     12.9
# 44      8.5
# 45     14.9
# 46     10.6
# 47     23.2
# 48     14.8
# 49      9.7
# 50     11.4
# 51     10.7
# 52     22.6
# 53     21.2
# 54     20.2
# 55     23.7
# 56      5.5
# 57     13.2
# 58     23.8
# 59     18.4
# 60      8.1
# 61     24.2
# 62     15.7
# 63     14.0
# 64     18.0
# 65      9.3
# 66      9.5
# 67     13.4
# 68     18.9
# 69     22.3
# 70     18.3
# 71     12.4
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# Importing all the Libraries required to build model

# %% [markdown]
# ### Finding Best Random State:-

# %%
MaxAccu=0
MaxRS=0

for i in range (1,500):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=i)
    lr=LinearRegression()
    lr.fit(x_train,y_train)
    predlr_train=lr.predict(x_train)
    predlr_test=lr.predict(x_test)
    acc=r2_score(y_test,predlr_test)
    if acc>MaxAccu:
        MaxAccu=acc
        MaxRS=i
print("Best Accuracy is ", MaxAccu, "on Random State ", MaxRS)
      
# Finding the Best Random State with Maximum R2 Score Accuracy
# Out:
# Best Accuracy is  0.9499160253751923 on Random State  444

# %% [markdown]
# ### Model Building using Linear Regression:-

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=444)

# Splitting the data into Train & Test using the best random state

# %%
x_train.shape
# Out:
# (148, 3)

# %%
y_train.shape
# Out:
# (148,)

# %%
x_test.shape
# Out:
# (50, 3)

# %%
y_test.shape
# Out:
# (50,)

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)

# Training the Linear Regression Model
# Out:
# LinearRegression()

# %%
lr_pred=lr.predict(x_test)
lr_pred

# The Linear Regression Model is predicting values based on training
# Out:
# array([ 9.73513159, 17.12934522, 19.69881524, 20.29743295, 21.42463158,
#        19.26015172, 16.30911063,  8.47585292,  9.86332488, 13.72206809,
#        21.01842195, 11.3680675 , 12.15915031, 19.48492468, 13.92683427,
#         7.83310505, 21.43106028, 20.55725611, 10.05404648, 17.61538318,
#        13.85565202, 20.22733013, 16.26132076, 16.16469968, 11.31029382,
#        18.25252863, 13.7372264 ,  8.19363082, 10.30372596, 24.46966508,
#        11.53974614, 14.9585567 , 23.15415453, 14.25892559, 15.13661173,
#         4.56739324, 10.49198349,  7.62482032, 11.64219596, 17.98930823,
#         9.02740518, 15.42630822, 14.14025005, 12.65493524, 14.86595938,
#         9.79343365,  9.93504503, 20.19416587, 12.02098268,  6.18370519])

# %%
lr.score(x_train,y_train)
# Out:
# 0.8747163493501431

# %%
print(r2_score(y_test,lr_pred))

# Giving the R2 Accuracy of Linear Regression Model
# Out:
# 0.9499160253751923

# %%
print(mean_absolute_error(y_test,lr_pred))
print(mean_squared_error(y_test,lr_pred))
print(np.sqrt(mean_squared_error(y_test,lr_pred)))

# Evolution Matrix of Linear Regression Model
# Out:
# 0.9311174482205793
# 1.3570120702898654
# 1.1649086102737267

# %% [markdown]
# ### Model Building using other Regressors:-

# %% [markdown]
# ### Decision Tree Regressor:-

# %%
from sklearn.tree import DecisionTreeRegressor

# Importing Decision Tree Regressor Model from sklearn Library

# %%
dtr=DecisionTreeRegressor(criterion="mse",max_depth=5,min_samples_split=5)
dtr.fit(x_train,y_train)

# Training the Decision Tree Regressor Model
# Out:
# DecisionTreeRegressor(max_depth=5, min_samples_split=5)

# %%
dtr.score(x_train,y_train)
# Out:
# 0.9835564490642886

# %%
dtr_pred=dtr.predict(x_test)
dtr_pred

# The Decision Tree Regressor Model is predicting values based on training
# Out:
# array([10.97142857, 18.86      , 18.86      , 23.03      , 18.9       ,
#        20.13333333, 16.2       , 10.26      , 10.97142857, 16.05      ,
#        18.86      ,  8.625     , 10.97142857, 18.86      , 12.31875   ,
#         8.625     , 18.9       , 18.86      , 10.36666667, 17.3       ,
#        14.82222222, 23.03      , 16.2       , 17.3       , 13.1       ,
#        20.13333333, 12.31875   , 10.26      ,  8.625     , 25.14      ,
#        11.9       , 16.05      , 25.14      , 10.97142857, 12.31875   ,
#         6.875     ,  8.625     ,  6.875     , 14.3       , 20.13333333,
#         8.625     , 11.9       , 14.82222222, 12.31875   , 14.82222222,
#        10.97142857, 10.97142857, 20.13333333, 12.16666667,  6.875     ])

# %%
print(r2_score(y_test,dtr_pred))

# R2 Accuracy Score of Decision Tree Regressor Model
# Out:
# 0.9208232504457059

# %%
print(mean_absolute_error(y_test,dtr_pred))
print(mean_squared_error(y_test,dtr_pred))
print(np.sqrt(mean_squared_error(y_test,dtr_pred)))

# Evolution Matrix of Decision Tree Regressor Model
# Out:
# 1.1180349206349207
# 2.1452731265117153
# 1.4646750924733154

# %% [markdown]
# ### Random Forest Regressor:-

# %%
from sklearn.ensemble import RandomForestRegressor

# Importing the Random Forest Regressor Model from sklearn Library

# %%
rfr=RandomForestRegressor()
rfr.fit(x_train,y_train)

# Training the Random Forest Regressor Model
# Out:
# RandomForestRegressor()

# %%
rfr.score(x_train,y_train)
# Out:
# 0.9968951879740316

# %%
rfr_pred=rfr.predict(x_test)
rfr_pred

# The Random Forest Regressor Model is predicting values based on training
# Out:
# array([10.698, 18.507, 19.915, 21.949, 20.079, 20.184, 16.527,  9.998,
#        10.55 , 14.485, 21.352,  7.565, 10.152, 19.83 , 12.67 ,  7.827,
#        19.786, 20.856, 10.633, 18.337, 14.412, 21.578, 16.388, 17.494,
#        12.6  , 19.425, 12.006,  9.682,  7.706, 24.836, 11.945, 15.13 ,
#        24.068, 12.447, 13.187,  7.214,  8.226,  7.195, 12.997, 18.698,
#         7.441, 13.772, 14.493, 11.864, 15.078, 10.862, 11.129, 20.071,
#        12.706,  7.15 ])

# %%
print(r2_score(y_test,rfr_pred))

# The R2 Accuracy Score of Random Forest Regressor Model
# Out:
# 0.9689819424703013

# %%
print(mean_absolute_error(y_test,rfr_pred))
print(mean_squared_error(y_test,rfr_pred))
print(np.sqrt(mean_squared_error(y_test,rfr_pred)))

# Evolution Matrix of Random Forest Regressor Model
# Out:
# 0.6886799999999996
# 0.8404260799999971
# 0.9167475552189911

# %% [markdown]
# ### Extra Trees Regressor:-

# %%
from sklearn.ensemble import ExtraTreesRegressor

# Importing the Extra Trees Regressor Model from sklearn Library

# %%
etr=ExtraTreesRegressor()
etr.fit(x_train,y_train)

# Training the Extra Trees Regressor Model
# Out:
# ExtraTreesRegressor()

# %%
etr.score(x_train,y_train)
# Out:
# 1.0

# %%
etr_pred=etr.predict(x_test)
etr_pred

# The Extra Trees Regressor Model is predicting values based on training
# Out:
# array([ 9.863, 18.388, 20.654, 21.876, 20.823, 20.   , 16.35 ,  9.979,
#         9.987, 14.639, 22.926,  8.729, 10.599, 20.602, 13.003,  7.421,
#        20.255, 21.977, 10.401, 18.563, 14.133, 21.577, 16.408, 16.899,
#        12.74 , 19.565, 11.7  ,  9.672,  8.572, 25.254, 11.82 , 15.668,
#        23.788, 13.373, 13.504,  6.671,  8.876,  7.033, 12.881, 18.269,
#         8.37 , 14.266, 14.386, 11.28 , 15.088,  9.948, 10.97 , 20.104,
#        12.155,  7.288])

# %%
print(r2_score(y_test,etr_pred))

# The R2 Accuracy Score of Extra Trees Regressor Model
# Out:
# 0.9878435582468861

# %%
print(mean_absolute_error(y_test,etr_pred))
print(mean_squared_error(y_test,etr_pred))
print(np.sqrt(mean_squared_error(y_test,etr_pred)))

# Evolution Matrix of Extra Trees Regressor Model
# Out:
# 0.41178000000000226
# 0.32937557999999845
# 0.5739125194661626

# %% [markdown]
# # Cross Validation:-

# %%
from sklearn.model_selection import cross_val_score

# Importing the Cross Validation function from sklearn Library

# %%
scr1=cross_val_score(lr, x, y, cv=5)
scr1
# Out:
# array([0.87927341, 0.91751522, 0.92568478, 0.81065809, 0.89557158])

# %%
print("The Cross Validation Score of Linear Regression Model is: ", scr1.mean())

# The Cross Validation Score of Linear Regression Model is: 0.8857406146589945
# Out:
# The Cross Validation Score of Linear Regression Model is:  0.8857406146589945

# %%
scr2=cross_val_score(dtr, x, y, cv=5)
scr2
# Out:
# array([0.9389426 , 0.95657756, 0.90079435, 0.89862697, 0.96474657])

# %%
print("The Cross Validation Score of Decision Tree Regressor Model is: ", scr2.mean())

# The Cross Validation Score of Decision Tree Regressor Model is: 0.9358201050579321
# Out:
# The Cross Validation Score of Decision Tree Regressor Model is:  0.9319376126647974

# %%
scr3=cross_val_score(rfr, x, y, cv=5)
scr3
# Out:
# array([0.98115551, 0.98430207, 0.97595386, 0.96194139, 0.9813662 ])

# %%
print("The Cross Validation Score of Random Forest Regressor Model is: ", scr3.mean())

# The Cross Validation Score of Random Forest Regressor Model is: 0.9766345476833147
# Out:
# The Cross Validation Score of Random Forest Regressor Model is:  0.976943806422713

# %%
scr4=cross_val_score(etr, x, y, cv=5)
scr4
# Out:
# array([0.99152766, 0.99266349, 0.9913382 , 0.97139174, 0.9881179 ])

# %%
print("The Cross Validation Score of Extra Trees Regressor Model is: ", scr4.mean())

# The Cross Validation Score of Extra Trees Regressor Model is: 0.9870531253086081
# Out:
# The Cross Validation Score of Extra Trees Regressor Model is:  0.987007797470133

# %% [raw]
# # As we can see that the best Accuracy and least difference in r2_score and Cross Validation is in Extra Trees Regressor Model, therefore, we will take it as the best performing model and will do hyper parameter tuning to find the best possible Accuracy.

# %% [markdown]
# # Hyper Parameter Tuning:-

# %%
from sklearn.model_selection import GridSearchCV

# importing the GridSearchCV function from sklearn Library to find best parameter for final model building

# %%
parameter={"max_depth":np.arange(2,10), 
           "criterion":["mse"],"min_samples_split":np.arange(2,10),
          "max_leaf_nodes":np.arange(2,10)}

# Taking the parameters based on which best model will be selected

# %%
GCV=GridSearchCV(ExtraTreesRegressor(),parameter,cv=5)

# %%
GCV.fit(x_train,y_train)

# Training the GCV Model for best parameters
# Out:
# GridSearchCV(cv=5, estimator=ExtraTreesRegressor(),
#              param_grid={'criterion': ['mse'],
#                          'max_depth': array([2, 3, 4, 5, 6, 7, 8, 9]),
#                          'max_leaf_nodes': array([2, 3, 4, 5, 6, 7, 8, 9]),
#                          'min_samples_split': array([2, 3, 4, 5, 6, 7, 8, 9])})

# %%
GCV.best_params_

# The Best Parameter we get for maximum R2 Accuracy is {'criterion': 'mse',
#  'max_depth': 5,
#  'max_leaf_nodes': 9,
#  'min_samples_split': 7}
# Out:
# {'criterion': 'mse',
#  'max_depth': 8,
#  'max_leaf_nodes': 9,
#  'min_samples_split': 7}

# %%
final_model=ExtraTreesRegressor(criterion="mse", max_depth=8,max_leaf_nodes=9,min_samples_split=7)
final_model.fit(x_train,y_train)
final_model_pred=final_model.predict(x_test)
acc=r2_score(y_test,final_model_pred)
print(acc*100)

# The final model with best parameter and maximum R2 Accuracy is 96.41%
# Out:
# 95.69163466887416

# %% [markdown]
# # Saving the Extra Trees Regressor Model (Serialization):-

# %%
import joblib

# Importing the Joblib function to perform Serialization

# %%
joblib.dump(final_model,"Advertising_Sales.obj")

# Saving the Final Model of Extra Trees Regressor in Advertising_Sales.obj file for deployment in the Industry
# Out:
# ['Advertising_Sales.obj']
