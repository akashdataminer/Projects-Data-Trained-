# %% [markdown]
# # Importing Libraries & Dataset:-

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import warnings
warnings.filterwarnings("ignore")

# Importing the required Libraries into Python

# %%
ds=pd.read_csv("Temperature_Forecast.csv")
ds

# Importing the Dataset into Python from the system
# Out:
#       station        Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  \
# 0         1.0  30-06-2013          28.7          21.4    58.255688
# 1         2.0  30-06-2013          31.9          21.6    52.263397
# 2         3.0  30-06-2013          31.6          23.3    48.690479
# 3         4.0  30-06-2013          32.0          23.4    58.239788
# 4         5.0  30-06-2013          31.4          21.9    56.174095
# ...       ...         ...           ...           ...          ...
# 7747     23.0  30-08-2017          23.3          17.1    26.741310
# 7748     24.0  30-08-2017          23.3          17.7    24.040634
# 7749     25.0  30-08-2017          23.2          17.4    22.933014
# 7750      NaN         NaN          20.0          11.3    19.794666
# 7751      NaN         NaN          37.6          29.9    98.524734
#
#       LDAPS_RHmax  LDAPS_Tmax_lapse  LDAPS_Tmin_lapse   LDAPS_WS    LDAPS_LH  \
# 0       91.116364         28.074101         23.006936   6.818887   69.451805
# ...

# %%
temperature=pd.DataFrame(data=ds)
temperature

# Giving the Dataset a Structured format with DataFrame and saving it in variable "temperature"
# Out:
#       station        Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  \
# 0         1.0  30-06-2013          28.7          21.4    58.255688
# 1         2.0  30-06-2013          31.9          21.6    52.263397
# 2         3.0  30-06-2013          31.6          23.3    48.690479
# 3         4.0  30-06-2013          32.0          23.4    58.239788
# 4         5.0  30-06-2013          31.4          21.9    56.174095
# ...       ...         ...           ...           ...          ...
# 7747     23.0  30-08-2017          23.3          17.1    26.741310
# 7748     24.0  30-08-2017          23.3          17.7    24.040634
# 7749     25.0  30-08-2017          23.2          17.4    22.933014
# 7750      NaN         NaN          20.0          11.3    19.794666
# 7751      NaN         NaN          37.6          29.9    98.524734
#
#       LDAPS_RHmax  LDAPS_Tmax_lapse  LDAPS_Tmin_lapse   LDAPS_WS    LDAPS_LH  \
# 0       91.116364         28.074101         23.006936   6.818887   69.451805
# ...

# %% [markdown]
# # EDA(Exploratory Data Analysis):-

# %%
temperature.columns

# Displaying the names of all the columns present in the dataset
# Out:
# Index(['station', 'Date', 'Present_Tmax', 'Present_Tmin', 'LDAPS_RHmin',
#        'LDAPS_RHmax', 'LDAPS_Tmax_lapse', 'LDAPS_Tmin_lapse', 'LDAPS_WS',
#        'LDAPS_LH', 'LDAPS_CC1', 'LDAPS_CC2', 'LDAPS_CC3', 'LDAPS_CC4',
#        'LDAPS_PPT1', 'LDAPS_PPT2', 'LDAPS_PPT3', 'LDAPS_PPT4', 'lat', 'lon',
#        'DEM', 'Slope', 'Solar radiation', 'Next_Tmax', 'Next_Tmin'],
#       dtype='object')

# %%
temperature.info()

# Displaying the column Data type and null values present
# We can see that all the columns are float continuous dtype except Date which is object dtype
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7752 entries, 0 to 7751
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   station           7750 non-null   float64
#  1   Date              7750 non-null   object
#  2   Present_Tmax      7682 non-null   float64
#  3   Present_Tmin      7682 non-null   float64
#  4   LDAPS_RHmin       7677 non-null   float64
#  5   LDAPS_RHmax       7677 non-null   float64
#  6   LDAPS_Tmax_lapse  7677 non-null   float64
#  7   LDAPS_Tmin_lapse  7677 non-null   float64
#  8   LDAPS_WS          7677 non-null   float64
#  9   LDAPS_LH          7677 non-null   float64
#  10  LDAPS_CC1         7677 non-null   float64
#  11  LDAPS_CC2         7677 non-null   float64
#  12  LDAPS_CC3         7677 non-null   float64
#  13  LDAPS_CC4         7677 non-null   float64
#  14  LDAPS_PPT1        7677 non-null   float64
#  15  LDAPS_PPT2        7677 non-null   float64
# ...

# %%
temperature.isnull().sum()

# Displaying all the null values present in the Dataset
# There are many null values present in the Dataset
# Out:
# station              2
# Date                 2
# Present_Tmax        70
# Present_Tmin        70
# LDAPS_RHmin         75
# LDAPS_RHmax         75
# LDAPS_Tmax_lapse    75
# LDAPS_Tmin_lapse    75
# LDAPS_WS            75
# LDAPS_LH            75
# LDAPS_CC1           75
# LDAPS_CC2           75
# LDAPS_CC3           75
# LDAPS_CC4           75
# LDAPS_PPT1          75
# LDAPS_PPT2          75
# LDAPS_PPT3          75
# LDAPS_PPT4          75
# lat                  0
# lon                  0
# DEM                  0
# Slope                0
# Solar radiation      0
# Next_Tmax           27
# Next_Tmin           27
# dtype: int64

# %%
plt.figure(figsize=(15,12))
plt.subplot(1,2,1)
sns.histplot(temperature['Present_Tmax'],kde=True,color='r')
plt.subplot(1,2,2)
sns.histplot(temperature['Present_Tmin'],kde=True,color='b')
print('Minimum Tmax is {} and Maximum Tmax is {}'.format(temperature['Present_Tmax'].min(),temperature['Present_Tmax'].max()))
print('Minimum Tmin is {} and Maximum Tmin is {}'.format(temperature['Present_Tmin'].min(),temperature['Present_Tmin'].max()))


# As we can see that both the Dataset of Present_Tmax & Present_Tmin are almost normally Distributed
# The highest Tmax temperature is 37.6 and lowest Tmax temperature is 20
# The highest Tmin temperature is 29.9 and lowest Tmin temperature is 11.3
# Out:
# Minimum Tmax is 20.0 and Maximum Tmax is 37.6
# Minimum Tmin is 11.3 and Maximum Tmin is 29.9

# %%
plt.figure(figsize=(15,8))
plt.subplot(1,2,1)
sns.histplot(temperature['LDAPS_RHmax'],kde=True,color='r')
plt.title('Maximum Relative Humidity (%)')
plt.subplot(1,2,2)
sns.histplot(temperature['LDAPS_RHmin'],kde=True,color='b')
plt.title('Minimum Relative Humidity (%)')
print('Minimum RHmax is {} and Maximum RHmax is {}'.format(temperature['LDAPS_RHmax'].min(),temperature['LDAPS_RHmax'].max()))
print('Minimum RHmin is {} and Maximum RHmin is {}'.format(temperature['LDAPS_RHmin'].min(),temperature['LDAPS_RHmin'].max()))


# We can see that Maximum Relative Humidity graph is left skewed and Minimum Relative Humidity graph is right skewed
# The highest Relative Humidity Maximum is 100 and lowest Relative Humidity Maximum is 58.93
# The highest Relative Humidity Minimum is 98.52 and lowest Relative Humidity Minimum is 19.79
# Out:
# Minimum RHmax is 58.93628311 and Maximum RHmax is 100.00015259999999
# Minimum RHmin is 19.79466629 and Maximum RHmin is 98.5247345

# %%
plt.figure(figsize=(15,8))
plt.subplot(1,2,1)
sns.histplot(temperature['LDAPS_Tmax_lapse'],kde=True,color='r')
plt.subplot(1,2,2)
sns.histplot(temperature['LDAPS_Tmin_lapse'],kde=True,color='b')
print('Minimum Tmax applied lapse rate is {} and Maximum Tmax applied lapse rate is {}'.format(temperature['LDAPS_Tmax_lapse'].min(),temperature['LDAPS_Tmax_lapse'].max()))
print('Minimum Tmin is applied lapse rate {} and Maximum Tmin applied lapse rate is {}'.format(temperature['LDAPS_Tmin_lapse'].min(),temperature['LDAPS_Tmin_lapse'].max()))


# The LDAPS_Tmax_lapse curve is almost a normally distributed curve while LDAPS_Tmin_lapse curve is slight left skewed
# The highest Tmax applied rate is 38.54 while lowest Tmax applied rate is 17.62
# The highest Tmin applied rate is 29.61 while lowest Tmin applied rate is 14.27
# Out:
# Minimum Tmax applied lapse rate is 17.62495378 and Maximum Tmax applied lapse rate is 38.54225522
# Minimum Tmin is applied lapse rate 14.27264631 and Maximum Tmin applied lapse rate is 29.61934244

# %%
plt.figure(figsize=(15,12))
plt.suptitle('Next day Maximum Temperature Vs Next day average Cloud Cover')

plt.subplot(2,2,1)
sns.regplot(x='LDAPS_CC1',y='Next_Tmax',data=temperature,marker='*',color='r')

plt.subplot(2,2,2)
sns.regplot(x='LDAPS_CC2',y='Next_Tmax',data=temperature,marker='*',color='r')

plt.subplot(2,2,3)
sns.regplot(x='LDAPS_CC3',y='Next_Tmax',data=temperature,marker='*',color='r')

plt.subplot(2,2,4)
sns.regplot(x='LDAPS_CC4',y='Next_Tmax',data=temperature,marker='*',color='r')

# The Graph is showing a negative relationship so it indicates that with increase in cloud covers the temperature decreases
# Out:
# <AxesSubplot:xlabel='LDAPS_CC4', ylabel='Next_Tmax'>

# %%
plt.figure(figsize=(15,12))
plt.suptitle('Next day Minimum Temperature Vs Next day average Cloud Cover')

plt.subplot(2,2,1)
sns.regplot(x='LDAPS_CC1',y='Next_Tmin',data=temperature,marker='*',color='b')

plt.subplot(2,2,2)
sns.regplot(x='LDAPS_CC2',y='Next_Tmin',data=temperature,marker='*',color='b')

plt.subplot(2,2,3)
sns.regplot(x='LDAPS_CC3',y='Next_Tmin',data=temperature,marker='*',color='b')

plt.subplot(2,2,4)
sns.regplot(x='LDAPS_CC4',y='Next_Tmin',data=temperature,marker='*',color='b')

# The Graph is showing a constant relation which means that increase in cloud cover doesnt effect much on min temperature
# Out:
# <AxesSubplot:xlabel='LDAPS_CC4', ylabel='Next_Tmin'>

# %%
plt.figure(figsize=(15,12))
plt.suptitle('Next day Maximum Temperature Vs Next day average Precipitation')

plt.subplot(2,2,1)
sns.regplot(x='LDAPS_PPT1',y='Next_Tmax',data=temperature,marker='*',color='r')

plt.subplot(2,2,2)
sns.regplot(x='LDAPS_PPT2',y='Next_Tmax',data=temperature,marker='*',color='r')

plt.subplot(2,2,3)
sns.regplot(x='LDAPS_PPT3',y='Next_Tmax',data=temperature,marker='*',color='r')

plt.subplot(2,2,4)
sns.regplot(x='LDAPS_PPT4',y='Next_Tmax',data=temperature,marker='*',color='r')

# The Graph shows a negative relation which means that Tmax Temperature decreases with increase in Percipitation
# Out:
# <AxesSubplot:xlabel='LDAPS_PPT4', ylabel='Next_Tmax'>

# %%
plt.figure(figsize=(15,12))
plt.suptitle('Next day Minimum Temperature Vs Next day average Precipitation')

plt.subplot(2,2,1)
sns.regplot(x='LDAPS_PPT1',y='Next_Tmin',data=temperature,marker='*',color='b')

plt.subplot(2,2,2)
sns.regplot(x='LDAPS_PPT2',y='Next_Tmin',data=temperature,marker='*',color='b')

plt.subplot(2,2,3)
sns.regplot(x='LDAPS_PPT3',y='Next_Tmin',data=temperature,marker='*',color='b')

plt.subplot(2,2,4)
sns.regplot(x='LDAPS_PPT4',y='Next_Tmin',data=temperature,marker='*',color='b')

# The Graph shows more of a constant relation which means that Tmin Temperature remains unchanged with Percipitation
# Out:
# <AxesSubplot:xlabel='LDAPS_PPT4', ylabel='Next_Tmin'>

# %%
plt.figure(figsize=(15,12))

plt.subplot(2,2,1)
sns.scatterplot(x='LDAPS_PPT1',y='LDAPS_CC1',hue='Next_Tmax',data=temperature)

plt.subplot(2,2,2)
sns.scatterplot(x='LDAPS_PPT2',y='LDAPS_CC2',hue='Next_Tmax',data=temperature)

plt.subplot(2,2,3)
sns.scatterplot(x='LDAPS_PPT3',y='LDAPS_CC3',hue='Next_Tmax',data=temperature)

plt.subplot(2,2,4)
sns.scatterplot(x='LDAPS_PPT4',y='LDAPS_CC4',hue='Next_Tmax',data=temperature)

# As can be seen from Darker dots that the TMax Temperature will increase with decrease in Cloud Cover and Percipitation
# There are few outliers also present in the Dataset as can be seen from few far away dots
# Out:
# <AxesSubplot:xlabel='LDAPS_PPT4', ylabel='LDAPS_CC4'>

# %%
plt.figure(figsize=(15,12))

plt.subplot(2,2,1)
sns.scatterplot(x='LDAPS_PPT1',y='LDAPS_CC1',hue='Next_Tmin',data=temperature)

plt.subplot(2,2,2)
sns.scatterplot(x='LDAPS_PPT2',y='LDAPS_CC2',hue='Next_Tmin',data=temperature)

plt.subplot(2,2,3)
sns.scatterplot(x='LDAPS_PPT3',y='LDAPS_CC3',hue='Next_Tmin',data=temperature)

plt.subplot(2,2,4)
sns.scatterplot(x='LDAPS_PPT4',y='LDAPS_CC4',hue='Next_Tmin',data=temperature)

# As can be seen from darker dots the TMin temperature decreases with increase in cloud cover and Percipitation
# There are few outliers present in the Dataset as can be seen from few far away dots
# Out:
# <AxesSubplot:xlabel='LDAPS_PPT4', ylabel='LDAPS_CC4'>

# %%
plt.figure(figsize=(20,15))
sns.heatmap(temperature.corr(),annot=True,cmap='coolwarm_r',linewidths=2, linecolor="black")

# There is a very high correlation of Next Tmax and Next Tmin with Present Tmax and Present Tmin
# There is a very high correlation of Next Tmax and Next Tmin with LDAPS_Tmax_Lapse and LDAPS_Tmin_Lapse
# Out:
# <AxesSubplot:>

# %%
temperature.drop(columns=["Date"],inplace=True)

# Dropping the Date Column

# %%
temperature.isnull().sum()

# Displaying the Missing Values present in each column
# Out:
# station              2
# Present_Tmax        70
# Present_Tmin        70
# LDAPS_RHmin         75
# LDAPS_RHmax         75
# LDAPS_Tmax_lapse    75
# LDAPS_Tmin_lapse    75
# LDAPS_WS            75
# LDAPS_LH            75
# LDAPS_CC1           75
# LDAPS_CC2           75
# LDAPS_CC3           75
# LDAPS_CC4           75
# LDAPS_PPT1          75
# LDAPS_PPT2          75
# LDAPS_PPT3          75
# LDAPS_PPT4          75
# lat                  0
# lon                  0
# DEM                  0
# Slope                0
# Solar radiation      0
# Next_Tmax           27
# Next_Tmin           27
# dtype: int64

# %%
temperature.dtypes

# Displaying the Data Types of all the columns present in the Dataset
# Out:
# station             float64
# Present_Tmax        float64
# Present_Tmin        float64
# LDAPS_RHmin         float64
# LDAPS_RHmax         float64
# LDAPS_Tmax_lapse    float64
# LDAPS_Tmin_lapse    float64
# LDAPS_WS            float64
# LDAPS_LH            float64
# LDAPS_CC1           float64
# LDAPS_CC2           float64
# LDAPS_CC3           float64
# LDAPS_CC4           float64
# LDAPS_PPT1          float64
# LDAPS_PPT2          float64
# LDAPS_PPT3          float64
# LDAPS_PPT4          float64
# lat                 float64
# lon                 float64
# DEM                 float64
# Slope               float64
# Solar radiation     float64
# Next_Tmax           float64
# Next_Tmin           float64
# dtype: object

# %%
temperature['station'].fillna(temperature['station'].median(),inplace=True)
temperature['Present_Tmax'].fillna(temperature['Present_Tmax'].median(),inplace=True)
temperature['Present_Tmin'].fillna(temperature['Present_Tmin'].median(),inplace=True)
temperature['LDAPS_RHmax'].fillna(temperature['LDAPS_RHmax'].median(),inplace=True)
temperature['LDAPS_RHmin'].fillna(temperature['LDAPS_RHmin'].median(),inplace=True)
temperature['LDAPS_Tmax_lapse'].fillna(temperature['LDAPS_Tmax_lapse'].median(),inplace=True)
temperature['LDAPS_Tmin_lapse'].fillna(temperature['LDAPS_Tmin_lapse'].median(),inplace=True)
temperature['LDAPS_WS'].fillna(temperature['LDAPS_WS'].median(),inplace=True)
temperature['LDAPS_LH'].fillna(temperature['LDAPS_LH'].median(),inplace=True)
temperature['LDAPS_CC1'].fillna(temperature['LDAPS_CC1'].median(),inplace=True)
temperature['LDAPS_CC2'].fillna(temperature['LDAPS_CC2'].median(),inplace=True)
temperature['LDAPS_CC3'].fillna(temperature['LDAPS_CC3'].median(),inplace=True)
temperature['LDAPS_CC4'].fillna(temperature['LDAPS_CC4'].median(),inplace=True)
temperature['LDAPS_PPT1'].fillna(temperature['LDAPS_PPT1'].median(),inplace=True)
temperature['LDAPS_PPT2'].fillna(temperature['LDAPS_PPT2'].median(),inplace=True)
temperature['LDAPS_PPT3'].fillna(temperature['LDAPS_PPT3'].median(),inplace=True)
temperature['LDAPS_PPT4'].fillna(temperature['LDAPS_PPT4'].median(),inplace=True)
temperature['Next_Tmax'].fillna(temperature['Next_Tmax'].median(),inplace=True)
temperature['Next_Tmin'].fillna(temperature['Next_Tmin'].median(),inplace=True)

# Filling the Missing Values of Columns with its Median

# %%
temperature.isnull().sum()

# Now we can see that there are no Missing Values present in the Dataset
# Out:
# station             0
# Present_Tmax        0
# Present_Tmin        0
# LDAPS_RHmin         0
# LDAPS_RHmax         0
# LDAPS_Tmax_lapse    0
# LDAPS_Tmin_lapse    0
# LDAPS_WS            0
# LDAPS_LH            0
# LDAPS_CC1           0
# LDAPS_CC2           0
# LDAPS_CC3           0
# LDAPS_CC4           0
# LDAPS_PPT1          0
# LDAPS_PPT2          0
# LDAPS_PPT3          0
# LDAPS_PPT4          0
# lat                 0
# lon                 0
# DEM                 0
# Slope               0
# Solar radiation     0
# Next_Tmax           0
# Next_Tmin           0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# Importing the Libraries required for training model

# %%
x=temperature.drop(columns=["Next_Tmax","Next_Tmin"])
y=temperature.iloc[:,22:]

# Taking the independent variables in x and target variables in y

# %%
x
# Out:
#       station  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0         1.0          28.7          21.4    58.255688    91.116364
# 1         2.0          31.9          21.6    52.263397    90.604721
# 2         3.0          31.6          23.3    48.690479    83.973587
# 3         4.0          32.0          23.4    58.239788    96.483688
# 4         5.0          31.4          21.9    56.174095    90.155128
# ...       ...           ...           ...          ...          ...
# 7747     23.0          23.3          17.1    26.741310    78.869858
# 7748     24.0          23.3          17.7    24.040634    77.294975
# 7749     25.0          23.2          17.4    22.933014    77.243744
# 7750     13.0          20.0          11.3    19.794666    58.936283
# 7751     13.0          37.6          29.9    98.524734   100.000153
#
#       LDAPS_Tmax_lapse  LDAPS_Tmin_lapse   LDAPS_WS    LDAPS_LH  LDAPS_CC1  \
# ...

# %%
y
# Out:
#       Next_Tmax  Next_Tmin
# 0          29.1       21.2
# 1          30.5       22.5
# 2          31.1       23.9
# 3          31.7       24.3
# 4          31.2       22.5
# ...         ...        ...
# 7747       28.3       18.1
# 7748       28.6       18.8
# 7749       27.8       17.4
# 7750       17.4       11.3
# 7751       38.9       29.8
#
# [7752 rows x 2 columns]

# %%
MaxAccu=0
MaxRS=0

for i in range (1,500):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=i)
    lr=LinearRegression()
    lr.fit(x_train,y_train)
    predlr_train=lr.predict(x_train)
    predlr_test=lr.predict(x_test)
    acc=r2_score(y_test,predlr_test)
    if acc>MaxAccu:
        MaxAccu=acc
        MaxRS=i
print("Best Accuracy is ", MaxAccu, "on Random State ", MaxRS)

# Finding the Best Random State with Maximum Accuracy
# Out:
# Best Accuracy is  0.8240167726856953 on Random State  160

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=160)

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)

# Training the Linear Regression Model
# Out:
# LinearRegression()

# %%
lr_pred=lr.predict(x_test)
lr_pred

# The Linear Regression Model is predicting values based on training
# Out:
# array([[25.80392385, 21.76294724],
#        [32.43551562, 24.3147118 ],
#        [22.36844907, 16.37532361],
#        ...,
#        [25.73433493, 20.87643118],
#        [30.11451365, 20.41516834],
#        [29.19449639, 24.0517625 ]])

# %%
print(r2_score(y_test,lr_pred))

# The R2 Accuracy Score of Linear Regression Model
# Out:
# 0.8240167726856953

# %% [markdown]
# ### Decision Tree Regressor:-

# %%
from sklearn.tree import DecisionTreeRegressor

# Importing the Decision Tree Regressor Model

# %%
MaxAccu=0
MaxRS=0

for i in range (1,500):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=i)
    dtr=DecisionTreeRegressor()
    dtr.fit(x_train,y_train)
    preddtr_train=dtr.predict(x_train)
    preddtr_test=dtr.predict(x_test)
    acc=r2_score(y_test,preddtr_test)
    if acc>MaxAccu:
        MaxAccu=acc
        MaxRS=i
print("Best Accuracy is ", MaxAccu, "on Random State ", MaxRS)

# Finding the Best Random State with Maximum Accuracy
# Out:
# Best Accuracy is  0.7864303895267384 on Random State  94

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=94)

# %%
dtr=DecisionTreeRegressor()
dtr.fit(x_train,y_train)

# Training the Decision Tree Regressor Model
# Out:
# DecisionTreeRegressor()

# %%
dtr_pred=dtr.predict(x_test)
dtr_pred

# The Decision Tree Regressor Model is predicting values based on training
# Out:
# array([[34.6, 22.1],
#        [30.6, 24.1],
#        [26.9, 20.4],
#        ...,
#        [32. , 22.1],
#        [23.2, 20.1],
#        [33.2, 25. ]])

# %%
print(r2_score(y_test,dtr_pred))

# The R2 Accuracy Score of Decision Tree Regressor Model
# Out:
# 0.7759461250038088

# %% [markdown]
# ### Random Forest Regressor:-

# %%
from sklearn.ensemble import RandomForestRegressor

# Importing the Random Forest Regressor Model

# %%
MaxAccu=0
MaxRS=0

for i in range (1,500):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=i)
    rfr=RandomForestRegressor()
    rfr.fit(x_train,y_train)
    predrfr_train=rfr.predict(x_train)
    predrfr_test=rfr.predict(x_test)
    acc=r2_score(y_test,predrfr_test)
    if acc>MaxAccu:
        MaxAccu=acc
        MaxRS=i
print("Best Accuracy is ", MaxAccu, "on Random State ", MaxRS)

# Finding the Best Random State with Maximum Accuracy
# Out:
# Best Accuracy is  0.9080153256709833 on Random State  12

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=12)

# %%
rfr=RandomForestRegressor()
rfr.fit(x_train,y_train)

# Training the Random Forest Regressor Model
# Out:
# RandomForestRegressor()

# %%
rfr_pred=rfr.predict(x_test)
rfr_pred

# The Random Forest Regressor Model is predicting values based on training
# Out:
# array([[33.132, 21.927],
#        [35.148, 27.25 ],
#        [35.512, 25.978],
#        ...,
#        [32.872, 23.658],
#        [31.751, 22.47 ],
#        [29.129, 23.364]])

# %%
print(r2_score(y_test,rfr_pred))

# The R2 Accuracy score of Random Forest Regressor Model
# Out:
# 0.9070132352841476

# %% [markdown]
# ### K Neighbors Regressor:-

# %%
from sklearn.neighbors import KNeighborsRegressor

# Importing the K Neighbors Regressor Model

# %%
MaxAccu=0
MaxRS=0

for i in range (1,500):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=i)
    knn=KNeighborsRegressor()
    knn.fit(x_train,y_train)
    predknn_train=knn.predict(x_train)
    predknn_test=knn.predict(x_test)
    acc=r2_score(y_test,predknn_test)
    if acc>MaxAccu:
        MaxAccu=acc
        MaxRS=i
print("Best Accuracy is ", MaxAccu, "on Random State ", MaxRS)

# Finding the Best Random State with Maximum Accuracy
# Out:
# Best Accuracy is  0.5721591372127894 on Random State  40

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=40)

# %%
knn=KNeighborsRegressor()
knn.fit(x_train,y_train)

# Training the K Neighbors Regressor Model
# Out:
# KNeighborsRegressor()

# %%
knn_pred=knn.predict(x_test)
knn_pred

# The K Neighbors Regressor Model is predicting values based on training
# Out:
# array([[33.18, 26.68],
#        [30.26, 24.14],
#        [30.38, 23.1 ],
#        ...,
#        [26.68, 22.84],
#        [30.7 , 23.32],
#        [31.18, 21.54]])

# %%
print(r2_score(y_test,knn_pred))

# The R2 Accuracy score of K Neighbors Regressor Model
# Out:
# 0.5721591372127894

# %% [markdown]
# # Cross Validation:-

# %%
from sklearn.model_selection import cross_val_score

# Importing the Cross Validation Score Function

# %%
scr1=cross_val_score(lr, x, y, cv=5)
scr1
# Out:
# array([0.69264656, 0.65440641, 0.75123124, 0.83035459, 0.77558433])

# %%
print("The Cross Validation Score of Linear Regression is: ", scr1.mean())
# Out:
# The Cross Validation Score of Linear Regression is:  0.7408446266971233

# %%
scr2=cross_val_score(dtr, x, y, cv=5)
scr2
# Out:
# array([0.26110299, 0.3184515 , 0.38753009, 0.71689493, 0.49906356])

# %%
print("The Cross Validation Score of Decision Tree Regressor is: ", scr2.mean())
# Out:
# The Cross Validation Score of Decision Tree Regressor is:  0.4366086118252106

# %%
scr3=cross_val_score(rfr, x, y, cv=5)
scr3
# Out:
# array([0.6429346 , 0.63537148, 0.69874559, 0.8301141 , 0.7482598 ])

# %%
print("The Cross Validation Score of Random Forest Regressor is: ", scr3.mean())
# Out:
# The Cross Validation Score of Random Forest Regressor is:  0.7110851132690789

# %%
scr4=cross_val_score(knn, x, y, cv=5)
scr4
# Out:
# array([ 0.16781367, -0.36944415,  0.10097019,  0.35097754,  0.25466504])

# %%
print("The Cross Validation Score of K Neighbors Regressor is: ", scr4.mean())
# Out:
# The Cross Validation Score of K Neighbors Regressor is:  0.10099645868989778

# %% [raw]
# # As we can see that Best Cross Validation Score is in Random Forest Regressor and we will choose it as the best performing Model

# %% [markdown]
# # Hyper Parameter Tuning:-

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameter={"max_depth":np.arange(2,10), 
           "criterion":["mse"],
          "min_samples_split":np.arange(2,10),
          "n_estimators":np.arange(2,10),
          "min_samples_leaf":np.arange(2,10)}

# Taking all the parameters to find the best Accuracy Score

# %%
GCV=GridSearchCV(RandomForestRegressor(),parameter,cv=5)

# %%
GCV.fit(x_train,y_train)

# Training the GridSearchCV model
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'criterion': ['mse'],
#                          'max_depth': array([2, 3, 4, 5, 6, 7, 8, 9]),
#                          'min_samples_leaf': array([2, 3, 4, 5, 6, 7, 8, 9]),
#                          'min_samples_split': array([2, 3, 4, 5, 6, 7, 8, 9]),
#                          'n_estimators': array([2, 3, 4, 5, 6, 7, 8, 9])})

# %%
GCV.best_params_

# Best Parameters are {'criterion': 'mse',
#  'max_depth': 9,
#  'min_samples_leaf': 3,
#  'min_samples_split': 3,
#  'n_estimators': 9}
# Out:
# {'criterion': 'mse',
#  'max_depth': 9,
#  'min_samples_leaf': 3,
#  'min_samples_split': 3,
#  'n_estimators': 9}

# %%
final_model=RandomForestRegressor(criterion="mse", max_depth=9, min_samples_leaf=3, min_samples_split=3, n_estimators=9)
final_model.fit(x_train,y_train)
final_model_pred=final_model.predict(x_test)
acc=r2_score(y_test,final_model_pred)
print(acc*100)
# Out:
# 86.19433376635473

# %% [markdown]
# # Saving the Random Forest Regressor Model (Serialization):-

# %%
import joblib

# importing the Joblib function to perform Serialization

# %%
joblib.dump(final_model,"Temperature_Model.obj")

# Dumping the Final model for deployment into the object file "Temperature_Model.obj"
# Out:
# ['Temperature_Model.obj']
